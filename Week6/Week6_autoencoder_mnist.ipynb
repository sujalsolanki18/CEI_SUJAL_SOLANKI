# %% [markdown]
# # Autoencoder MNIST

# %% [markdown]
# ## Importing required packages

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import torch 
import torch.nn as nn 
import torch.nn.functional as F
from  torch.utils.data import DataLoader, SubsetRandomSampler
import torch.optim
from torchvision import datasets,transforms

# %% [markdown]
# ## Defining transforms

# %%
transforms=transforms.ToTensor()

# %% [markdown]
# ## Downloading requried data

# %%
train_data=datasets.MNIST('data',train=True,download=True,transform=transforms)
test_data=datasets.MNIST('data',train=False,download=True,transform=transforms)

# %% [markdown]
# ## Defining dataloaders

# %%
valid_size=0.2

# IMPORTANT 
batch_size=20

num_workers=0

train_length = len(train_data)

# obtain training dataset indices that will be used for validation dataset
indices = list(range(train_length))

np.random.shuffle(indices)
split = int(np.floor(valid_size * train_length))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders for train, test and validation dataset
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)

# %%
# Printing the length of our train, valid and test dataloaders
# NOTE : Here batch size is 20
len(train_loader),len(valid_loader),len(test_loader)
# Out:
# (2400, 600, 500)

# %%
# checking our data
dataiter = iter(train_loader)
images, labels = next(dataiter)

print(images.shape)
print(labels.shape)
# Out:
# torch.Size([20, 1, 28, 28])
# torch.Size([20])

# %% [markdown]
# ## Visualizing a Training batch

# %%
# Displaying images and labels of a batch
fig=plt.figure(figsize=(30,10))
for i in range(len(labels)):
    ax=fig.add_subplot(2,10,i+1,xticks=[],yticks=[])
    plt.imshow(np.squeeze(images[i]))
    ax.set_title(labels[i].item(),color='blue')

# %% [markdown]
# ## Defining Architecture

# %%
class F_Auto_MNIST(nn.Module):
    def __init__(self,en_dim):
        super(F_Auto_MNIST,self).__init__()
        self.encoder=nn.Linear(784,en_dim)
        self.decoder=nn.Linear(en_dim,784)
    
    def forward(self,x):
        x=F.relu(self.encoder(x))
        x=F.sigmoid(self.decoder(x))
        return x

class Tran_conv_Auto_MNIST(nn.Module):
    def __init__(self):
        super(Tran_conv_Auto_MNIST,self).__init__()
        self.en_conv1=nn.Conv2d(1,16,3,padding=1)
        self.en_conv2=nn.Conv2d(16,4,3,padding=1)
        self.pool=nn.MaxPool2d(2,2)

        self.de_conv1=nn.ConvTranspose2d(4,16,2,stride=2)
        self.de_conv2=nn.ConvTranspose2d(16,1,2,stride=2)

    def forward(self,x):
        x=self.pool(F.relu(self.en_conv1(x)))
        x=self.pool(F.relu(self.en_conv2(x)))
        x=F.relu(self.de_conv1(x))
        x=F.sigmoid(self.de_conv2(x))
        return x

class upsamp_conv_Auto_MNIST(nn.Module):
    def __init__(self):
        super(upsamp_conv_Auto_MNIST,self).__init__()
        self.en_conv1=nn.Conv2d(1,16,3,padding=1)
        self.en_conv2=nn.Conv2d(16,4,3,padding=1)
        self.pool=nn.MaxPool2d(2,2)

        self.de_conv1=nn.Conv2d(4,16,3,padding=1)
        self.de_conv2=nn.Conv2d(16,1,3,padding=1)

    def forward(self,x):
        x=self.pool(F.relu(self.en_conv1(x)))
        x=self.pool(F.relu(self.en_conv2(x)))
        x = F.upsample(x, scale_factor=2, mode='nearest')
        x=F.relu(self.de_conv1(x))
        x = F.upsample(x, scale_factor=2, mode='nearest')
        x=F.sigmoid(self.de_conv2(x))
        return x

#Since the images are normalized between 0 and 1, we need to use a sigmoid activation on the output layer to get values that match this input value range.

# %%
model_1=F_Auto_MNIST(32)
model_2=Tran_conv_Auto_MNIST()
model_3=upsamp_conv_Auto_MNIST()

def weight_init_normal(m):
    classname=m.__class__.__name__
    if classname.find('Linear')!=-1:
        n = m.in_features
        y = (1.0/np.sqrt(n))
        m.weight.data.normal_(0, y)
        m.bias.data.fill_(0)

model_1.apply(weight_init_normal)

use_cuda=True
if use_cuda and torch.cuda.is_available():
  model_1.cuda()
  model_2.cuda()
  model_3.cuda()
print(model_1,'\n\n\n\n',model_2,'\n\n\n\n',model_3,'\n\n\n\n','On GPU : ',torch.cuda.is_available())
# Out:
# F_Auto_MNIST(
#   (encoder): Linear(in_features=784, out_features=32, bias=True)
#   (decoder): Linear(in_features=32, out_features=784, bias=True)
# )
#
#
#
#  Tran_conv_Auto_MNIST(
#   (en_conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (en_conv2): Conv2d(16, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (de_conv1): ConvTranspose2d(4, 16, kernel_size=(2, 2), stride=(2, 2))
#   (de_conv2): ConvTranspose2d(16, 1, kernel_size=(2, 2), stride=(2, 2))
# )
#
#
#
#  upsamp_conv_Auto_MNIST(
#   (en_conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (en_conv2): Conv2d(16, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (de_conv1): Conv2d(4, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (de_conv2): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
#
#
#
#  On GPU :  False

# %% [markdown]
# ## Defining our Loss Function

# %%
# Used when comapring pixel values.
criterion=nn.MSELoss()

# %% [markdown]
# ## Training and Validation Phase

# %%
def trainNet(model,lr,state='fully'):
    optimizer=torch.optim.Adam(model.parameters(),lr=lr)

    # Number of epochs to train for
    loss_keeper={'train':[],'valid':[]}
    epochs=20

    # minimum validation loss ----- set initial minimum to infinity
    valid_loss_min = np.inf

    for epoch in range(epochs):
        train_loss=0.0
        valid_loss=0.0

        """
        TRAINING PHASE
        """
        model.train() # TURN ON DROPOUT for training
        for images,_ in train_loader:
            if use_cuda and torch.cuda.is_available():
                images=images.cuda()
            if state=='fully':
                images=images.view(images.size(0),-1)
            optimizer.zero_grad()
            output=model(images)
            loss=criterion(output,images)
            loss.backward()
            optimizer.step()
            train_loss+=loss.item()

        """
        VALIDATION PHASE
        """
        model.eval() # TURN OFF DROPOUT for validation
        for images,_ in valid_loader:
            if use_cuda and torch.cuda.is_available():
                images=images.cuda()
            if state=='fully':
                images=images.view(images.size(0),-1)
            output=model(images)
            loss=criterion(output,images)
            valid_loss+=loss.item()

        # Calculating loss over entire batch size for every epoch
        train_loss = train_loss/len(train_loader)
        valid_loss = valid_loss/len(valid_loader)


        # saving loss values
        loss_keeper['train'].append(train_loss)
        loss_keeper['valid'].append(valid_loss)

        print(f"\nEpoch : {epoch+1}\tTraining Loss : {train_loss}\tValidation Loss : {valid_loss}")
        if valid_loss<=valid_loss_min:
            print(f"Validation loss decreased from : {valid_loss_min} ----> {valid_loss} ----> Saving Model.......")
            z=type(model).__name__
            torch.save(model.state_dict(), z+'_model.pth')
            valid_loss_min=valid_loss
    return(loss_keeper)

# %%
m1_loss=trainNet(model_1,0.01)
# Out:
# Epoch : 1	Training Loss : 0.02819100665471827	Validation Loss : 0.024274176973849534
# Validation loss decreased from : inf ----> 0.024274176973849534 ----> Saving Model.......
#
# Epoch : 2	Training Loss : 0.024307269863396264	Validation Loss : 0.02401480416456858
# Validation loss decreased from : 0.024274176973849534 ----> 0.02401480416456858 ----> Saving Model.......
#
# Epoch : 3	Training Loss : 0.023965304922312497	Validation Loss : 0.024153880172719557
#
# Epoch : 4	Training Loss : 0.023744310127416006	Validation Loss : 0.02359944177636256
# Validation loss decreased from : 0.02401480416456858 ----> 0.02359944177636256 ----> Saving Model.......
#
# Epoch : 5	Training Loss : 0.023648611281532794	Validation Loss : 0.023288550333430368
# Validation loss decreased from : 0.02359944177636256 ----> 0.023288550333430368 ----> Saving Model.......
#
# Epoch : 6	Training Loss : 0.023562759084937473	Validation Loss : 0.023371661587928732
#
# Epoch : 7	Training Loss : 0.02351223547787716	Validation Loss : 0.023719401073952515
#
# Epoch : 8	Training Loss : 0.02347631738948015	Validation Loss : 0.023653979968900483
#
# Epoch : 9	Training Loss : 0.023441177592224752	Validation Loss : 0.02326681667007506
# Validation loss decreased from : 0.023288550333430368 ----> 0.02326681667007506 ----> Saving Model.......
#
# Epoch : 10	Training Loss : 0.023404816195834427	Validation Loss : 0.02340447934344411
#
# Epoch : 11	Training Loss : 0.0233838534875152	Validation Loss : 0.0232698949581633
#
# Epoch : 12	Training Loss : 0.023330979590537027	Validation Loss : 0.023167582995568713
# Validation loss decreased from : 0.02326681667007506 ----> 0.023167582995568713 ----> Saving Model.......
#
# Epoch : 13	Training Loss : 0.023325041584515323	Validation Loss : 0.023243245100602508
#
# Epoch : 14	Training Loss : 0.02329732133541256	Validation Loss : 0.02313502169835071
# Validation loss decreased from : 0.023167582995568713 ----> 0.02313502169835071 ----> Saving Model.......
#
# Epoch : 15	Training Loss : 0.023292443156630423	Validation Loss : 0.023124433485791088
# Validation loss decreased from : 0.02313502169835071 ----> 0.023124433485791088 ----> Saving Model.......
#
# Epoch : 16	Training Loss : 0.023287635495653377	Validation Loss : 0.0232959640926371
#
# Epoch : 17	Training Loss : 0.02328230610350147	Validation Loss : 0.023212999782214562
#
# Epoch : 18	Training Loss : 0.02331096513235631	Validation Loss : 0.02301764161636432
# Validation loss decreased from : 0.023124433485791088 ----> 0.02301764161636432 ----> Saving Model.......
#
# Epoch : 19	Training Loss : 0.023254103999740133	Validation Loss : 0.02337491773379346
#
# Epoch : 20	Training Loss : 0.023299206123532108	Validation Loss : 0.023054728830854097

# %%
m2_loss=trainNet(model_2,0.01,'conv')
# Out:
# Epoch : 1	Training Loss : 0.04577831035169462	Validation Loss : 0.042387643698602914
# Validation loss decreased from : inf ----> 0.042387643698602914 ----> Saving Model.......
#
# Epoch : 2	Training Loss : 0.041192697946292656	Validation Loss : 0.03800008750520647
# Validation loss decreased from : 0.042387643698602914 ----> 0.03800008750520647 ----> Saving Model.......
#
# Epoch : 3	Training Loss : 0.035300602513986326	Validation Loss : 0.03434811487173041
# Validation loss decreased from : 0.03800008750520647 ----> 0.03434811487173041 ----> Saving Model.......
#
# Epoch : 4	Training Loss : 0.034301678432772556	Validation Loss : 0.03382880631213387
# Validation loss decreased from : 0.03434811487173041 ----> 0.03382880631213387 ----> Saving Model.......
#
# Epoch : 5	Training Loss : 0.03399059810830901	Validation Loss : 0.03384029572208722
#
# Epoch : 6	Training Loss : 0.033855985077874115	Validation Loss : 0.03373126657679677
# Validation loss decreased from : 0.03382880631213387 ----> 0.03373126657679677 ----> Saving Model.......
#
# Epoch : 7	Training Loss : 0.03374540076823905	Validation Loss : 0.033523076738541324
# Validation loss decreased from : 0.03373126657679677 ----> 0.033523076738541324 ----> Saving Model.......
#
# Epoch : 8	Training Loss : 0.03364698309218511	Validation Loss : 0.03353028962388635
#
# Epoch : 9	Training Loss : 0.03361389584451293	Validation Loss : 0.03347783649961154
# Validation loss decreased from : 0.033523076738541324 ----> 0.03347783649961154 ----> Saving Model.......
#
# Epoch : 10	Training Loss : 0.03358831056859344	Validation Loss : 0.033442010286574564
# Validation loss decreased from : 0.03347783649961154 ----> 0.033442010286574564 ----> Saving Model.......
#
# Epoch : 11	Training Loss : 0.033491011635245135	Validation Loss : 0.033298399861281115
# Validation loss decreased from : 0.033442010286574564 ----> 0.033298399861281115 ----> Saving Model.......
#
# Epoch : 12	Training Loss : 0.03339685474134361	Validation Loss : 0.03323855622050663
# Validation loss decreased from : 0.033298399861281115 ----> 0.03323855622050663 ----> Saving Model.......
#
# Epoch : 13	Training Loss : 0.03327863461260373	Validation Loss : 0.03308225939050317
# Validation loss decreased from : 0.03323855622050663 ----> 0.03308225939050317 ----> Saving Model.......
#
# Epoch : 14	Training Loss : 0.03325960313901305	Validation Loss : 0.03294110077122847
# Validation loss decreased from : 0.03308225939050317 ----> 0.03294110077122847 ----> Saving Model.......
#
# Epoch : 15	Training Loss : 0.03325678837252781	Validation Loss : 0.03292452803812921
# Validation loss decreased from : 0.03294110077122847 ----> 0.03292452803812921 ----> Saving Model.......
#
# Epoch : 16	Training Loss : 0.033214126486176006	Validation Loss : 0.032991636140892906
#
# Epoch : 17	Training Loss : 0.033185544554144145	Validation Loss : 0.03283955523433785
# Validation loss decreased from : 0.03292452803812921 ----> 0.03283955523433785 ----> Saving Model.......
#
# Epoch : 18	Training Loss : 0.0333665607854103	Validation Loss : 0.033544180430471894
#
# Epoch : 19	Training Loss : 0.033338234474261604	Validation Loss : 0.03434796039946377
#
# Epoch : 20	Training Loss : 0.03331863476041084	Validation Loss : 0.0330719946231693

# %%
m3_loss=trainNet(model_3,0.01,'conv')
# Out:
# /var/folders/98/g26wy2d54m727kzzxfvlss340000gn/T/ipykernel_2468/219568314.py:42: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   x = F.upsample(x, scale_factor=2, mode='nearest')
# /var/folders/98/g26wy2d54m727kzzxfvlss340000gn/T/ipykernel_2468/219568314.py:44: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   x = F.upsample(x, scale_factor=2, mode='nearest')
# Epoch : 1	Training Loss : 0.11225087116161982	Validation Loss : 0.11179252812017997
# Validation loss decreased from : inf ----> 0.11179252812017997 ----> Saving Model.......
#
# Epoch : 2	Training Loss : 0.11205509222112596	Validation Loss : 0.11179252825677395
#
# Epoch : 3	Training Loss : 0.11205509236703316	Validation Loss : 0.11179252846787373
#
# Epoch : 4	Training Loss : 0.11205509249741832	Validation Loss : 0.11179252825677395
#
# Epoch : 5	Training Loss : 0.11205509263711672	Validation Loss : 0.11179252850512664
#
# Epoch : 6	Training Loss : 0.11205509241049488	Validation Loss : 0.11179252799600363
# Validation loss decreased from : 0.11179252812017997 ----> 0.11179252799600363 ----> Saving Model.......
#
# Epoch : 7	Training Loss : 0.11205509239186844	Validation Loss : 0.11179252836853265
#
# Epoch : 8	Training Loss : 0.11205509256571532	Validation Loss : 0.11179252816985051
#
# Epoch : 9	Training Loss : 0.1120550924508522	Validation Loss : 0.11179252864172061
#
# Epoch : 10	Training Loss : 0.11205509233598908	Validation Loss : 0.11179252830644448
#
# Epoch : 11	Training Loss : 0.11205509233909348	Validation Loss : 0.11179252838095029
#
# Epoch : 12	Training Loss : 0.11205509246637424	Validation Loss : 0.11179252830644448
#
# Epoch : 13	Training Loss : 0.11205509248810509	Validation Loss : 0.11179252833127976
#
# Epoch : 14	Training Loss : 0.112055092304945	Validation Loss : 0.11179252843062083
#
# Epoch : 15	Training Loss : 0.11205509211557607	Validation Loss : 0.11179252828160922
#
# Epoch : 16	Training Loss : 0.11205509241980811	Validation Loss : 0.11179252875347932
#
# Epoch : 17	Training Loss : 0.11205509229873617	Validation Loss : 0.11179252850512664
#
# Epoch : 18	Training Loss : 0.11205509219008188	Validation Loss : 0.11179252821952104
#
# Epoch : 19	Training Loss : 0.11205509237013757	Validation Loss : 0.11179252846787373
#
# Epoch : 20	Training Loss : 0.11205509230184059	Validation Loss : 0.1117925284182032

# %%
model_1.load_state_dict(torch.load('F_Auto_MNIST_model.pth'))
model_2.load_state_dict(torch.load('Tran_conv_Auto_MNIST_model.pth'))
model_3.load_state_dict(torch.load('upsamp_conv_Auto_MNIST_model.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Plotting Loss

# %%
title=['FFNN','Transpose CNN','Upsampled CNN']
model_losses=[m1_loss,m2_loss,m3_loss]

fig=plt.figure(1,figsize=(25,5))
idx=1
for i in model_losses:
  ax=fig.add_subplot(1,3,idx)
  ax.plot(i['train'],label="Training Loss")
  ax.plot(i['valid'],label="Validation Loss")
  ax.set_title('MNIST Autoencoder: '+title[idx-1])
  idx+=1
  plt.legend();

# %% [markdown]
# ## Testing Phase

# %%
def test(model,state='fully'):
    # obtain one batch of test images
    dataiter = iter(test_loader)
    images, _ = dataiter.next()
    if use_cuda and torch.cuda.is_available():
        images=images.cuda()
    if state=='fully':
        images = images.view(images.size(0), -1)

    # get sample outputs
    output = model(images)
    # prep images for display
    images = images.cpu().numpy()
    # output is resized into a batch of images
    output = output.view(batch_size, 1, 28, 28)
    # use detach when it's an output that requires_grad
    output = output.cpu().detach().numpy()


    # plot the first ten input images and then reconstructed images
    fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(25,4))

    # input images on top row, reconstructions on bottom
    for images, row in zip([images, output], axes):
        for img, ax in zip(images, row):
            if state=='fully':
                img = img.reshape(1, 28, 28)
            ax.imshow(np.squeeze(img), cmap='gray')
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)

# %% [markdown]
# ## FFNN Autoencoder

# %%
test(model_1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 test(model_1)
#
# Cell In[17], line 4, in test(model, state)
#       1 def test(model,state='fully'):
#       2     # obtain one batch of test images
#       3     dataiter = iter(test_loader)
# ----> 4     images, _ = dataiter.next()
#       5     if use_cuda and torch.cuda.is_available():
#       6         images=images.cuda()
#
# AttributeError: '_SingleProcessDataLoaderIter' object has no attribute 'next'

# %% [markdown]
# ## Transpose CNN Autoencoder

# %%
test(model_2,'conv')

# %% [markdown]
# ## Upsampled CNN Autoencoder

# %%
test(model_3,'conv')
